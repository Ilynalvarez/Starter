# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Ilynalvarez/Starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
lane = "California Housing "
query = "House Inquiries"
check = lane if query else "freestyle"
print(check)
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# California Housing

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
decision = "Housing Inquiry recommendation accuracy"
actor = "Home buyer or renter"
wrong_call_cost = {
    "overpriced_property": "overpayment",
    "unsuitable_property": "wasted on inspection/fees",
    "lost_opporutnity": "missed chance to secure ideal home"
}

query = f"Decision: {decision}, Actor: {actor}, Cost: {wrong_call_cost}"
check =True if decision and actor and wrong_call_cost else False

print(query)
print("check passed:", check)
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Decision: Housing Inquiry recommendation accuracy, Actor: Home buyer or renter, Cost: {'overpriced_property': 'overpayment', 'unsuitable_property': 'wasted on inspection/fees', 'lost_opporutnity': 'missed chance to secure ideal home'}
# check passed: True

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
import pandas as pd, numpy as np

df = pd.read_csv("/content/sample_data/california_housing_train.csv")

print(df.shape[0], "rows", df.shape[1], "columns")
df.head(3)
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# 17000 rows 9 columns
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
observed = "Buyers/Renter completed 62% of preventive tasks"
directional =" Engagement with reminders increases task completion"
decision_support = "Evidence supports better scheduling decisions"

cannot_claim = [
    "Causal proof of buying/renting outcomes",
    "Predicting Google or External systems",
    "Absolute guarantees of future behavior"
]

print("Can claim", observed, directional, decision_support)
print("Cannot claim:", cannot_claim)
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# Out:
# Can claim Buyers/Renter completed 62% of preventive tasks  Engagement with reminders increases task completion Evidence supports better scheduling decisions
# Cannot claim: ['Causal proof of buying/renting outcomes', 'Predicting Google or External systems', 'Absolute guarantees of future behavior']

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
